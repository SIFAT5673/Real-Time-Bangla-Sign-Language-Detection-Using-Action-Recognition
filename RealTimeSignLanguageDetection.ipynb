# %% [markdown]
# # LSTM Sign Language Detection by Abhishek Das & Sifatul Huq
#
# ![image.png](attachment:0b26aaca-5df4-46a1-85e5-22de21a18df9.png)
#
# ## B.Sc. in Computer Science and Engineering
# ## Patuakhali Science and Technology University
# #### Under the guidance of Prof. Dr. Md. Abdul Masud

# %% [markdown]
# **LSTM MODEL**
# 1. Install and import dependencies
# 2. Keypoints using MP Holistic
# 3. Extract Keypoints
# 4. Setup Folders for Collection
# 5. Collect Keypoints Values for Training and Testing
# 6. Preprocess Data and Create Labels and Features
# 7. Build and Train LSTM Neural Network
# 8. Make Predictions
# 9. Save Weights
# 10. Evaluation using Confusion Matrix and Accuracy
# 11. Test in Real Time

# %% [markdown]
# # Install and Import Dependencies

# %%
# !pip install tensorflow opencv-python mediapipe scikit-learn matplotlib tensorflowjs
# Out:
# Requirement already satisfied: tensorflow in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (2.15.1)
# Requirement already satisfied: opencv-python in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (4.10.0.84)
# Requirement already satisfied: mediapipe in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (0.10.14)
# Requirement already satisfied: scikit-learn in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (1.5.2)
# Requirement already satisfied: matplotlib in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (3.9.2)
# Requirement already satisfied: tensorflowjs in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (4.21.0)
# Requirement already satisfied: tensorflow-intel==2.15.1 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (2.15.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow) (0.3.2)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow) (4.25.5)
# Requirement already satisfied: setuptools in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow) (4.12.2)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow) (1.66.2)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.15.1->tensorflow) (2.15.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from mediapipe) (24.2.0)
# Requirement already satisfied: jax in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from mediapipe) (0.4.34)
# Requirement already satisfied: jaxlib in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from mediapipe) (0.4.34)
# Requirement already satisfied: opencv-contrib-python in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from mediapipe) (4.10.0.84)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from mediapipe) (0.5.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.54.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: pillow>=8 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: flax>=0.7.2 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from tensorflowjs) (0.9.0)
# Requirement already satisfied: importlib_resources>=5.9.0 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from tensorflowjs) (6.4.5)
# Requirement already satisfied: tf-keras>=2.13.0 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from tensorflowjs) (2.15.1)
# Requirement already satisfied: tensorflow-decision-forests>=1.5.0 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from tensorflowjs) (1.8.1)
# Requirement already satisfied: tensorflow-hub>=0.16.1 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from tensorflowjs) (0.16.1)
# Requirement already satisfied: msgpack in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from flax>=0.7.2->tensorflowjs) (1.1.0)
# Requirement already satisfied: optax in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from flax>=0.7.2->tensorflowjs) (0.2.3)
# Requirement already satisfied: orbax-checkpoint in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from flax>=0.7.2->tensorflowjs) (0.6.4)
# Requirement already satisfied: tensorstore in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from flax>=0.7.2->tensorflowjs) (0.1.66)
# Requirement already satisfied: rich>=11.1 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from flax>=0.7.2->tensorflowjs) (13.9.2)
# Requirement already satisfied: PyYAML>=5.4.1 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from flax>=0.7.2->tensorflowjs) (6.0.2)
# Requirement already satisfied: CFFI>=1.0 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.17.1)
# Requirement already satisfied: pandas in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (2.2.3)
# Requirement already satisfied: wheel in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (0.44.0)
# Requirement already satisfied: wurlitzer in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (3.1.1)
# Requirement already satisfied: pycparser in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from rich>=11.1->flax>=0.7.2->tensorflowjs) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from rich>=11.1->flax>=0.7.2->tensorflowjs) (2.18.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow) (2.35.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow) (1.2.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow) (3.0.4)
# Requirement already satisfied: chex>=0.1.86 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from optax->flax>=0.7.2->tensorflowjs) (0.1.87)
# Requirement already satisfied: etils[epy] in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from optax->flax>=0.7.2->tensorflowjs) (1.9.4)
# Requirement already satisfied: nest_asyncio in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (1.6.0)
# Requirement already satisfied: humanize in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (4.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from pandas->tensorflow-decision-forests>=1.5.0->tensorflowjs) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from pandas->tensorflow-decision-forests>=1.5.0->tensorflowjs) (2024.2)
# Requirement already satisfied: toolz>=0.9.0 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from chex>=0.1.86->optax->flax>=0.7.2->tensorflowjs) (1.0.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow) (2.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax>=0.7.2->tensorflowjs) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow) (2.1.5)
# Requirement already satisfied: fsspec in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.7.2->tensorflowjs) (2024.9.0)
# Requirement already satisfied: zipp in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.7.2->tensorflowjs) (3.20.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\acl-05\appdata\local\programs\python\python311\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.1->tensorflow) (3.2.2)

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp
# Out:
# WARNING:tensorflow:From C:\Users\Acl-05\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# # Keypoints using MP Holistic

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR-CONVERSION BGR-to-RGB
    image.flags.writeable = False                  # Convert image to not-writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Convert image to writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR-COVERSION RGB-to-BGR
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION) # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

# %%
def draw_styled_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)

        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# C:\Users\Acl-05\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %%
draw_landmarks(frame, results)

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # Extract Keypoint Values

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %% [markdown]
# # Setup Folders for Collection

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('MP_Data') 

# Actions that we try to detect
actions = np.array(['Hello','Shuvo Shokal','Apni','Kemon','Achen','Ami','Valo Achi','Ajker','Dinta','Shundor','Mach','Doya kore','Dekhte','SOS','Koita Baje','Dukkhito','Dhonnobad','Shahajjo Korte Pari','Bagh','Boi','Mobile','2','Ashirbad'])

# Thirty videos worth of data
no_sequences = 30

# Videos are going to be 30 frames in length
sequence_length = 30

# Folder start
start_folder = 30

# %%
signs = ['Hello','Shuvo Shokal','Apni','Kemon','Achen','Ami','Valo Achi','Ajker','Dinta','Shundor','Mach','Doya kore','Dekhte','SOS','Koita Baje','Dukkhito','Dhonnobad','Shahajjo Korte Pari','Bagh','Boi','Mobile','2','Ashirbad']

parent_folder = 'MP_Data'

if not os.path.exists(parent_folder):
    os.mkdir(parent_folder)
    for sign in signs:
        sign_folder = os.path.join(parent_folder, sign)
        os.mkdir(sign_folder)
        for i in range(30):
            subfolder = os.path.join(sign_folder, str(i))
            os.mkdir(subfolder)

# %% [markdown]
# # Collect Keypoint Values for Training and Testing

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    # NEW LOOP
    # Loop through actions
    for action in actions:
        # Loop through sequences aka videos
        for sequence in range(no_sequences):
            # Loop through video length aka sequence length
            for frame_num in range(sequence_length):

                # Read feed
                ret, frame = cap.read()

                # Make detections
                image, results = mediapipe_detection(frame, holistic)

                # Draw landmarks
                draw_styled_landmarks(image, results)
                
                # NEW Apply wait logic
                if frame_num == 0: 
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(500)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                
                # NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    cap.release()
    cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Preprocess Data and Create Labels and Features

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'Hello': 0,
#  'Shuvo Shokal': 1,
#  'Apni': 2,
#  'Kemon': 3,
#  'Achen': 4,
#  'Ami': 5,
#  'Valo Achi': 6,
#  'Ajker': 7,
#  'Dinta': 8,
#  'Shundor': 9,
#  'Mach': 10,
#  'Doya kore': 11,
#  'Dekhte': 12,
#  'SOS': 13,
#  'Koita Baje': 14,
#  'Dukkhito': 15,
#  'Dhonnobad': 16,
#  'Shahajjo Korte Pari': 17,
#  'Bagh': 18,
#  'Boi': 19,
#  'Mobile': 20,
#  '2': 21,
#  'Ashirbad': 22}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
X = np.array(sequences)

# %%
y = to_categorical(labels).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %% [markdown]
# # Build and Train LSTM Neural Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)
#While training access tensorboard
#tensorboard --logdir=.

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))
# Out:
# WARNING:tensorflow:From C:\Users\Acl-05\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\Acl-05\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.fit(X_train, y_train, epochs=2000, callbacks=[tb_callback])
# Out:
# Epoch 1/2000
# WARNING:tensorflow:From C:\Users\Acl-05\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Acl-05\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 21/21 [==============================] - 4s 38ms/step - loss: 3.1158 - categorical_accuracy: 0.0580
# Epoch 2/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 3.3319 - categorical_accuracy: 0.0931
# Epoch 3/2000
# 21/21 [==============================] - 1s 35ms/step - loss: 2.9998 - categorical_accuracy: 0.1252
# Epoch 4/2000
# 21/21 [==============================] - 1s 35ms/step - loss: 2.7930 - categorical_accuracy: 0.1328
# Epoch 5/2000
# 21/21 [==============================] - 1s 35ms/step - loss: 2.8117 - categorical_accuracy: 0.1618
# Epoch 6/2000
# 21/21 [==============================] - 1s 35ms/step - loss: 2.7202 - categorical_accuracy: 0.1679
# Epoch 7/2000
# 21/21 [==============================] - 1s 35ms/step - loss: 2.6600 - categorical_accuracy: 0.1756
# Epoch 8/2000
# 21/21 [==============================] - 1s 35ms/step - loss: 2.4736 - categorical_accuracy: 0.2366
# Epoch 9/2000
# 21/21 [==============================] - 1s 35ms/step - loss: 2.4404 - categorical_accuracy: 0.2183
# Epoch 10/2000
# 21/21 [==============================] - 1s 35ms/step - loss: 2.1716 - categorical_accuracy: 0.2794
# Epoch 11/2000
# 21/21 [==============================] - 1s 35ms/step - loss: 2.4344 - categorical_accuracy: 0.2382
# Epoch 12/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 2.0692 - categorical_accuracy: 0.3313
# Epoch 13/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 5.6909 - categorical_accuracy: 0.1634
# Epoch 14/2000
# 21/21 [==============================] - 1s 41ms/step - loss: 3.0278 - categorical_accuracy: 0.0824
# Epoch 15/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 3.0307 - categorical_accuracy: 0.0855
# Epoch 16/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 3.0107 - categorical_accuracy: 0.0824
# Epoch 17/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 2.9924 - categorical_accuracy: 0.0870
# Epoch 18/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 2.9290 - categorical_accuracy: 0.1069
# Epoch 19/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 2.8063 - categorical_accuracy: 0.1435
# Epoch 20/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 2.7081 - categorical_accuracy: 0.1542
# Epoch 21/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 2.6090 - categorical_accuracy: 0.1435
# Epoch 22/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 2.4116 - categorical_accuracy: 0.1328
# Epoch 23/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 2.3705 - categorical_accuracy: 0.1649
# Epoch 24/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 2.2968 - categorical_accuracy: 0.1908
# Epoch 25/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 2.2318 - categorical_accuracy: 0.2290
# Epoch 26/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 2.0812 - categorical_accuracy: 0.2122
# Epoch 27/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 2.1038 - categorical_accuracy: 0.2382
# Epoch 28/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 2.4193 - categorical_accuracy: 0.2489
# Epoch 29/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 2.2691 - categorical_accuracy: 0.2427
# Epoch 30/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 3.4362 - categorical_accuracy: 0.1740
# Epoch 31/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 6.1891 - categorical_accuracy: 0.1069
# Epoch 32/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 5.4643 - categorical_accuracy: 0.1023
# Epoch 33/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 3.8586 - categorical_accuracy: 0.1038
# Epoch 34/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 3.6375 - categorical_accuracy: 0.0763
# Epoch 35/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 2.8429 - categorical_accuracy: 0.1511
# Epoch 36/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 2.7267 - categorical_accuracy: 0.1496
# Epoch 37/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 5.0532 - categorical_accuracy: 0.1771
# Epoch 38/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 17.9684 - categorical_accuracy: 0.1771
# Epoch 39/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 4.9875 - categorical_accuracy: 0.2290
# Epoch 40/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 3.3404 - categorical_accuracy: 0.2641
# Epoch 41/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 2.9395 - categorical_accuracy: 0.2626
# Epoch 42/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 2.1330 - categorical_accuracy: 0.2748
# Epoch 43/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 1.9629 - categorical_accuracy: 0.3374
# Epoch 44/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 2.4169 - categorical_accuracy: 0.2519
# Epoch 45/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 6.9155 - categorical_accuracy: 0.1099
# Epoch 46/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 3.2072 - categorical_accuracy: 0.0916
# Epoch 47/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 3.0774 - categorical_accuracy: 0.0641
# Epoch 48/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 3.0155 - categorical_accuracy: 0.0809
# Epoch 49/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 2.9969 - categorical_accuracy: 0.0870
# Epoch 50/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 2.9751 - categorical_accuracy: 0.1038
# Epoch 51/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 2.9567 - categorical_accuracy: 0.0977
# Epoch 52/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 2.9398 - categorical_accuracy: 0.0947
# Epoch 53/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 2.9304 - categorical_accuracy: 0.1023
# Epoch 54/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 2.8846 - categorical_accuracy: 0.1176
# Epoch 55/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 2.8341 - categorical_accuracy: 0.1282
# Epoch 56/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 2.7558 - categorical_accuracy: 0.1481
# Epoch 57/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 2.9349 - categorical_accuracy: 0.1328
# Epoch 58/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 2.7716 - categorical_accuracy: 0.1389
# Epoch 59/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 2.6822 - categorical_accuracy: 0.1405
# Epoch 60/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 2.6192 - categorical_accuracy: 0.1573
# Epoch 61/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 2.5789 - categorical_accuracy: 0.1679
# Epoch 62/2000
# 21/21 [==============================] - 1s 40ms/step - loss: 2.5349 - categorical_accuracy: 0.1679
# Epoch 63/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 2.4627 - categorical_accuracy: 0.1985
# Epoch 64/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 2.4765 - categorical_accuracy: 0.2122
# Epoch 65/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 2.3843 - categorical_accuracy: 0.2473
# Epoch 66/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 2.4763 - categorical_accuracy: 0.1969
# Epoch 67/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 2.4232 - categorical_accuracy: 0.2122
# Epoch 68/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 2.3268 - categorical_accuracy: 0.2580
# Epoch 69/2000
# 21/21 [==============================] - 1s 42ms/step - loss: 2.3424 - categorical_accuracy: 0.2550
# Epoch 70/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 2.3432 - categorical_accuracy: 0.2565
# Epoch 71/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 2.2629 - categorical_accuracy: 0.2718
# Epoch 72/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 2.2387 - categorical_accuracy: 0.2840
# Epoch 73/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 2.1807 - categorical_accuracy: 0.3099
# Epoch 74/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 2.2005 - categorical_accuracy: 0.3298
# Epoch 75/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 2.2159 - categorical_accuracy: 0.2977
# Epoch 76/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 2.1797 - categorical_accuracy: 0.3237
# Epoch 77/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 2.1631 - categorical_accuracy: 0.3344
# Epoch 78/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 2.0807 - categorical_accuracy: 0.3481
# Epoch 79/2000
# 21/21 [==============================] - 1s 40ms/step - loss: 2.0902 - categorical_accuracy: 0.3618
# Epoch 80/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 2.0662 - categorical_accuracy: 0.3863
# Epoch 81/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 2.1304 - categorical_accuracy: 0.3221
# Epoch 82/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 2.0354 - categorical_accuracy: 0.3634
# Epoch 83/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 2.0090 - categorical_accuracy: 0.3832
# Epoch 84/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 1.9396 - categorical_accuracy: 0.4061
# Epoch 85/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 1.9616 - categorical_accuracy: 0.3832
# Epoch 86/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 1.9530 - categorical_accuracy: 0.3908
# Epoch 87/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 1.9737 - categorical_accuracy: 0.3817
# Epoch 88/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 1.9628 - categorical_accuracy: 0.3802
# Epoch 89/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 1.8987 - categorical_accuracy: 0.3878
# Epoch 90/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 1.8308 - categorical_accuracy: 0.4260
# Epoch 91/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 1.8487 - categorical_accuracy: 0.4137
# Epoch 92/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 1.8269 - categorical_accuracy: 0.4137
# Epoch 93/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 1.8075 - categorical_accuracy: 0.4183
# Epoch 94/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 1.7938 - categorical_accuracy: 0.4275
# Epoch 95/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 1.7498 - categorical_accuracy: 0.4366
# Epoch 96/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 1.8659 - categorical_accuracy: 0.4015
# Epoch 97/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 1.8643 - categorical_accuracy: 0.3954
# Epoch 98/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 1.7516 - categorical_accuracy: 0.4214
# Epoch 99/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 1.9761 - categorical_accuracy: 0.4382
# Epoch 100/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 2.0012 - categorical_accuracy: 0.4504
# Epoch 101/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 3.0984 - categorical_accuracy: 0.1710
# Epoch 102/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 2.8891 - categorical_accuracy: 0.1359
# Epoch 103/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 2.5348 - categorical_accuracy: 0.2122
# Epoch 104/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 2.1156 - categorical_accuracy: 0.3008
# Epoch 105/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 2.0654 - categorical_accuracy: 0.3405
# Epoch 106/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 2.3091 - categorical_accuracy: 0.2779
# Epoch 107/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 2.0854 - categorical_accuracy: 0.3985
# Epoch 108/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 1.7759 - categorical_accuracy: 0.3847
# Epoch 109/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 1.7653 - categorical_accuracy: 0.3542
# Epoch 110/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 1.7085 - categorical_accuracy: 0.4061
# Epoch 111/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 2.3288 - categorical_accuracy: 0.2290
# Epoch 112/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 1.8898 - categorical_accuracy: 0.3374
# Epoch 113/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 1.6077 - categorical_accuracy: 0.4122
# Epoch 114/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 1.5639 - categorical_accuracy: 0.4153
# Epoch 115/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 1.5146 - categorical_accuracy: 0.4351
# Epoch 116/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 1.4099 - categorical_accuracy: 0.4702
# Epoch 117/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 1.5613 - categorical_accuracy: 0.4397
# Epoch 118/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 1.3250 - categorical_accuracy: 0.5206
# Epoch 119/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 1.2399 - categorical_accuracy: 0.5237
# Epoch 120/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 1.1981 - categorical_accuracy: 0.5573
# Epoch 121/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 1.1071 - categorical_accuracy: 0.6092
# Epoch 122/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 1.1287 - categorical_accuracy: 0.5786
# Epoch 123/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 1.2365 - categorical_accuracy: 0.5420
# Epoch 124/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 1.2512 - categorical_accuracy: 0.5511
# Epoch 125/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 1.0212 - categorical_accuracy: 0.6397
# Epoch 126/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 1.1045 - categorical_accuracy: 0.6122
# Epoch 127/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 1.1165 - categorical_accuracy: 0.5878
# Epoch 128/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 0.8811 - categorical_accuracy: 0.6840
# Epoch 129/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 0.7978 - categorical_accuracy: 0.6794
# Epoch 130/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 1.0888 - categorical_accuracy: 0.5771
# Epoch 131/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 1.0505 - categorical_accuracy: 0.5985
# Epoch 132/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 0.8378 - categorical_accuracy: 0.6885
# Epoch 133/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 0.7889 - categorical_accuracy: 0.7053
# Epoch 134/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 0.7435 - categorical_accuracy: 0.6977
# Epoch 135/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 0.7385 - categorical_accuracy: 0.7145
# Epoch 136/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 0.7300 - categorical_accuracy: 0.7145
# Epoch 137/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 0.6645 - categorical_accuracy: 0.7313
# Epoch 138/2000
# 21/21 [==============================] - 1s 42ms/step - loss: 0.8375 - categorical_accuracy: 0.7023
# Epoch 139/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 0.6840 - categorical_accuracy: 0.7679
# Epoch 140/2000
# 21/21 [==============================] - 1s 40ms/step - loss: 0.6768 - categorical_accuracy: 0.7466
# Epoch 141/2000
# 21/21 [==============================] - 1s 40ms/step - loss: 0.6205 - categorical_accuracy: 0.7740
# Epoch 142/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 0.6922 - categorical_accuracy: 0.7344
# Epoch 143/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 0.6367 - categorical_accuracy: 0.7695
# Epoch 144/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 0.7785 - categorical_accuracy: 0.7008
# Epoch 145/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 0.6509 - categorical_accuracy: 0.7756
# Epoch 146/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 0.5250 - categorical_accuracy: 0.8000
# Epoch 147/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 0.4694 - categorical_accuracy: 0.8397
# Epoch 148/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 0.5352 - categorical_accuracy: 0.8214
# Epoch 149/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 0.5437 - categorical_accuracy: 0.8015
# Epoch 150/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 0.6472 - categorical_accuracy: 0.7710
# Epoch 151/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 0.6783 - categorical_accuracy: 0.7603
# Epoch 152/2000
# 21/21 [==============================] - 1s 40ms/step - loss: 1.0368 - categorical_accuracy: 0.5954
# Epoch 153/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 0.7407 - categorical_accuracy: 0.7313
# Epoch 154/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 0.4961 - categorical_accuracy: 0.8458
# Epoch 155/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 0.4231 - categorical_accuracy: 0.8458
# Epoch 156/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 0.6145 - categorical_accuracy: 0.7786
# Epoch 157/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 0.5060 - categorical_accuracy: 0.8183
# Epoch 158/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 0.4222 - categorical_accuracy: 0.8550
# Epoch 159/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 0.4008 - categorical_accuracy: 0.8626
# Epoch 160/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 0.4786 - categorical_accuracy: 0.8427
# Epoch 161/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 0.4753 - categorical_accuracy: 0.8275
# Epoch 162/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 0.4998 - categorical_accuracy: 0.8122
# Epoch 163/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 0.4826 - categorical_accuracy: 0.8137
# Epoch 164/2000
# 21/21 [==============================] - 1s 40ms/step - loss: 0.4176 - categorical_accuracy: 0.8656
# Epoch 165/2000
# 21/21 [==============================] - 1s 35ms/step - loss: 0.3705 - categorical_accuracy: 0.8687
# Epoch 166/2000
# 21/21 [==============================] - 1s 35ms/step - loss: 0.7385 - categorical_accuracy: 0.8366
# Epoch 167/2000
# 21/21 [==============================] - 1s 35ms/step - loss: 0.5989 - categorical_accuracy: 0.7786
# Epoch 168/2000
# 21/21 [==============================] - 1s 35ms/step - loss: 0.4320 - categorical_accuracy: 0.8672
# Epoch 169/2000
# 21/21 [==============================] - 1s 35ms/step - loss: 0.7449 - categorical_accuracy: 0.7405
# Epoch 170/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 0.5436 - categorical_accuracy: 0.8153
# Epoch 171/2000
# 21/21 [==============================] - 1s 35ms/step - loss: 0.4228 - categorical_accuracy: 0.8687
# Epoch 172/2000
# 21/21 [==============================] - 1s 35ms/step - loss: 0.3165 - categorical_accuracy: 0.9038
# Epoch 173/2000
# 21/21 [==============================] - 1s 35ms/step - loss: 0.4196 - categorical_accuracy: 0.8519
# Epoch 174/2000
# 21/21 [==============================] - 1s 35ms/step - loss: 0.5754 - categorical_accuracy: 0.7786
# Epoch 175/2000
# 21/21 [==============================] - 1s 35ms/step - loss: 0.4040 - categorical_accuracy: 0.8855
# Epoch 176/2000
# 21/21 [==============================] - 1s 35ms/step - loss: 0.3682 - categorical_accuracy: 0.8947
# Epoch 177/2000
# 21/21 [==============================] - 1s 35ms/step - loss: 2.5375 - categorical_accuracy: 0.4183
# Epoch 178/2000
# 21/21 [==============================] - 1s 35ms/step - loss: 2.0831 - categorical_accuracy: 0.2840
# Epoch 179/2000
# 21/21 [==============================] - 1s 35ms/step - loss: 1.7438 - categorical_accuracy: 0.4137
# Epoch 180/2000
# 21/21 [==============================] - 1s 35ms/step - loss: 2.1747 - categorical_accuracy: 0.5267
# Epoch 181/2000
# 21/21 [==============================] - 1s 35ms/step - loss: 1.0962 - categorical_accuracy: 0.6122
# Epoch 182/2000
# 21/21 [==============================] - 1s 35ms/step - loss: 0.8546 - categorical_accuracy: 0.7405
# Epoch 183/2000
# 21/21 [==============================] - 1s 35ms/step - loss: 0.7333 - categorical_accuracy: 0.7939
# Epoch 184/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 0.6501 - categorical_accuracy: 0.8092
# Epoch 185/2000
# 21/21 [==============================] - 1s 35ms/step - loss: 0.5520 - categorical_accuracy: 0.8351
# Epoch 186/2000
# 21/21 [==============================] - 1s 35ms/step - loss: 0.7654 - categorical_accuracy: 0.8092
# Epoch 187/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 0.6569 - categorical_accuracy: 0.7771
# Epoch 188/2000
# 21/21 [==============================] - 1s 35ms/step - loss: 0.5249 - categorical_accuracy: 0.8305
# Epoch 189/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 0.4524 - categorical_accuracy: 0.8550
# Epoch 190/2000
# 21/21 [==============================] - 1s 35ms/step - loss: 0.5226 - categorical_accuracy: 0.8061
# Epoch 191/2000
# 21/21 [==============================] - 1s 44ms/step - loss: 0.5272 - categorical_accuracy: 0.8183
# Epoch 192/2000
# 21/21 [==============================] - 1s 35ms/step - loss: 0.4490 - categorical_accuracy: 0.8321
# Epoch 193/2000
# 21/21 [==============================] - 1s 35ms/step - loss: 0.3543 - categorical_accuracy: 0.8962
# Epoch 194/2000
# 21/21 [==============================] - 1s 35ms/step - loss: 0.3737 - categorical_accuracy: 0.8687
# Epoch 195/2000
# 21/21 [==============================] - 1s 35ms/step - loss: 0.6876 - categorical_accuracy: 0.7649
# Epoch 196/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 0.5609 - categorical_accuracy: 0.7969
# Epoch 197/2000
# 21/21 [==============================] - 1s 35ms/step - loss: 0.3788 - categorical_accuracy: 0.8794
# Epoch 198/2000
# 21/21 [==============================] - 1s 35ms/step - loss: 0.3702 - categorical_accuracy: 0.8809
# Epoch 199/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 0.3690 - categorical_accuracy: 0.8748
# Epoch 200/2000
# 21/21 [==============================] - 1s 35ms/step - loss: 0.4208 - categorical_accuracy: 0.8626
# Epoch 201/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 0.3678 - categorical_accuracy: 0.8779
# Epoch 202/2000
# 21/21 [==============================] - 1s 41ms/step - loss: 0.2856 - categorical_accuracy: 0.9053
# Epoch 203/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 0.2347 - categorical_accuracy: 0.9344
# Epoch 204/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 0.5475 - categorical_accuracy: 0.8061
# Epoch 205/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 2.5781 - categorical_accuracy: 0.4366
# Epoch 206/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 2.3532 - categorical_accuracy: 0.2244
# Epoch 207/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 1.8101 - categorical_accuracy: 0.3878
# Epoch 208/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 1.5632 - categorical_accuracy: 0.4687
# Epoch 209/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 1.4104 - categorical_accuracy: 0.4947
# Epoch 210/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 1.2271 - categorical_accuracy: 0.5344
# Epoch 211/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 1.1999 - categorical_accuracy: 0.5313
# Epoch 212/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 1.0285 - categorical_accuracy: 0.5969
# Epoch 213/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 0.8629 - categorical_accuracy: 0.6840
# Epoch 214/2000
# 21/21 [==============================] - 1s 41ms/step - loss: 0.8346 - categorical_accuracy: 0.7298
# Epoch 215/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 0.7120 - categorical_accuracy: 0.7511
# Epoch 216/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 0.6653 - categorical_accuracy: 0.7786
# Epoch 217/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 1.0177 - categorical_accuracy: 0.7740
# Epoch 218/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 0.7634 - categorical_accuracy: 0.7359
# Epoch 219/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 0.5134 - categorical_accuracy: 0.8382
# Epoch 220/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 0.8599 - categorical_accuracy: 0.7359
# Epoch 221/2000
# 21/21 [==============================] - 1s 42ms/step - loss: 0.7840 - categorical_accuracy: 0.7145
# Epoch 222/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 0.5797 - categorical_accuracy: 0.8244
# Epoch 223/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 0.4943 - categorical_accuracy: 0.8305
# Epoch 224/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 0.5102 - categorical_accuracy: 0.8382
# Epoch 225/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 0.4097 - categorical_accuracy: 0.8687
# Epoch 226/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 0.3681 - categorical_accuracy: 0.8779
# Epoch 227/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 0.3792 - categorical_accuracy: 0.8656
# Epoch 228/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 0.4699 - categorical_accuracy: 0.8580
# Epoch 229/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 0.3345 - categorical_accuracy: 0.9053
# Epoch 230/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 0.3034 - categorical_accuracy: 0.8992
# Epoch 231/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 0.2875 - categorical_accuracy: 0.8992
# Epoch 232/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 0.3399 - categorical_accuracy: 0.8809
# Epoch 233/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 0.4318 - categorical_accuracy: 0.8427
# Epoch 234/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 0.4478 - categorical_accuracy: 0.8733
# Epoch 235/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 0.5727 - categorical_accuracy: 0.8473
# Epoch 236/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 0.5080 - categorical_accuracy: 0.8748
# Epoch 237/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 0.3792 - categorical_accuracy: 0.8794
# Epoch 238/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 0.3661 - categorical_accuracy: 0.8901
# Epoch 239/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 0.4111 - categorical_accuracy: 0.8992
# Epoch 240/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 0.3286 - categorical_accuracy: 0.8809
# Epoch 241/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 0.2642 - categorical_accuracy: 0.9191
# Epoch 242/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 0.3402 - categorical_accuracy: 0.8916
# Epoch 243/2000
# 21/21 [==============================] - 1s 40ms/step - loss: 0.2425 - categorical_accuracy: 0.9221
# Epoch 244/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 0.3652 - categorical_accuracy: 0.9084
# Epoch 245/2000
# 21/21 [==============================] - 1s 41ms/step - loss: 0.5872 - categorical_accuracy: 0.7832
# Epoch 246/2000
# 21/21 [==============================] - 1s 40ms/step - loss: 0.4378 - categorical_accuracy: 0.8748
# Epoch 247/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 0.3004 - categorical_accuracy: 0.8992
# Epoch 248/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 0.2370 - categorical_accuracy: 0.9298
# Epoch 249/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 0.2726 - categorical_accuracy: 0.9115
# Epoch 250/2000
# 21/21 [==============================] - 1s 41ms/step - loss: 0.4063 - categorical_accuracy: 0.8550
# Epoch 251/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 0.2526 - categorical_accuracy: 0.9099
# Epoch 252/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 0.2257 - categorical_accuracy: 0.9237
# Epoch 253/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 0.4133 - categorical_accuracy: 0.8656
# Epoch 254/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 0.3270 - categorical_accuracy: 0.8809
# Epoch 255/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 0.2409 - categorical_accuracy: 0.9145
# Epoch 256/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 0.2638 - categorical_accuracy: 0.9115
# Epoch 257/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 0.2724 - categorical_accuracy: 0.9130
# Epoch 258/2000
# 21/21 [==============================] - 1s 40ms/step - loss: 0.1850 - categorical_accuracy: 0.9450
# Epoch 259/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 0.1604 - categorical_accuracy: 0.9527
# Epoch 260/2000
# 21/21 [==============================] - 1s 41ms/step - loss: 0.2558 - categorical_accuracy: 0.9084
# Epoch 261/2000
# 21/21 [==============================] - 1s 49ms/step - loss: 0.4511 - categorical_accuracy: 0.8641
# Epoch 262/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 0.4630 - categorical_accuracy: 0.8473
# Epoch 263/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 0.2464 - categorical_accuracy: 0.9221
# Epoch 264/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 0.1609 - categorical_accuracy: 0.9527
# Epoch 265/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 0.1471 - categorical_accuracy: 0.9557
# Epoch 266/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 0.1316 - categorical_accuracy: 0.9603
# Epoch 267/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 0.1497 - categorical_accuracy: 0.9496
# Epoch 268/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 0.1784 - categorical_accuracy: 0.9527
# Epoch 269/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 0.1682 - categorical_accuracy: 0.9466
# Epoch 270/2000
# 21/21 [==============================] - 1s 45ms/step - loss: 0.1372 - categorical_accuracy: 0.9573
# Epoch 271/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 0.1514 - categorical_accuracy: 0.9496
# Epoch 272/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 0.5047 - categorical_accuracy: 0.9557
# Epoch 273/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 7.3071 - categorical_accuracy: 0.5817
# Epoch 274/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 2.8460 - categorical_accuracy: 0.1374
# Epoch 275/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 2.3070 - categorical_accuracy: 0.2519
# Epoch 276/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 2.0091 - categorical_accuracy: 0.3756
# Epoch 277/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 1.7485 - categorical_accuracy: 0.4687
# Epoch 278/2000
# 21/21 [==============================] - 1s 41ms/step - loss: 1.6374 - categorical_accuracy: 0.4779
# Epoch 279/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 1.4353 - categorical_accuracy: 0.5099
# Epoch 280/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 2.2132 - categorical_accuracy: 0.2916
# Epoch 281/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 2.0346 - categorical_accuracy: 0.2992
# Epoch 282/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 1.7469 - categorical_accuracy: 0.4076
# Epoch 283/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 1.7082 - categorical_accuracy: 0.4046
# Epoch 284/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 1.6473 - categorical_accuracy: 0.4290
# Epoch 285/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 1.4667 - categorical_accuracy: 0.5282
# Epoch 286/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 1.3576 - categorical_accuracy: 0.5481
# Epoch 287/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 1.3283 - categorical_accuracy: 0.5695
# Epoch 288/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 1.1224 - categorical_accuracy: 0.6229
# Epoch 289/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 1.1255 - categorical_accuracy: 0.6214
# Epoch 290/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 1.0078 - categorical_accuracy: 0.6779
# Epoch 291/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 0.9457 - categorical_accuracy: 0.7191
# Epoch 292/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 1.5518 - categorical_accuracy: 0.4702
# Epoch 293/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 1.2066 - categorical_accuracy: 0.5832
# Epoch 294/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 1.0487 - categorical_accuracy: 0.6641
# Epoch 295/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 1.2112 - categorical_accuracy: 0.6779
# Epoch 296/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 7.0530 - categorical_accuracy: 0.6122
# Epoch 297/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 13.3265 - categorical_accuracy: 0.6870
# Epoch 298/2000
# 21/21 [==============================] - 1s 40ms/step - loss: 2.0036 - categorical_accuracy: 0.4092
# Epoch 299/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 1.5841 - categorical_accuracy: 0.4794
# Epoch 300/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 1.5033 - categorical_accuracy: 0.5328
# Epoch 301/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 1.2967 - categorical_accuracy: 0.6809
# Epoch 302/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 4.7237 - categorical_accuracy: 0.6809
# Epoch 303/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 0.9172 - categorical_accuracy: 0.7282
# Epoch 304/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 1.1915 - categorical_accuracy: 0.6183
# Epoch 305/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 1.0739 - categorical_accuracy: 0.6489
# Epoch 306/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 0.8957 - categorical_accuracy: 0.7176
# Epoch 307/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 0.8185 - categorical_accuracy: 0.7130
# Epoch 308/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 0.6787 - categorical_accuracy: 0.7756
# Epoch 309/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 0.6688 - categorical_accuracy: 0.7939
# Epoch 310/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 0.6321 - categorical_accuracy: 0.7939
# Epoch 311/2000
# 21/21 [==============================] - 1s 36ms/step - loss: 0.7619 - categorical_accuracy: 0.7542
# Epoch 312/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 0.5918 - categorical_accuracy: 0.8214
# Epoch 313/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 0.5410 - categorical_accuracy: 0.8168
# Epoch 314/2000
# 21/21 [==============================] - 1s 35ms/step - loss: 0.6995 - categorical_accuracy: 0.8534
# Epoch 315/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 0.4648 - categorical_accuracy: 0.8595
# Epoch 316/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 0.4872 - categorical_accuracy: 0.8595
# Epoch 317/2000
# 21/21 [==============================] - 1s 40ms/step - loss: 0.4306 - categorical_accuracy: 0.8611
# Epoch 318/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 0.4769 - categorical_accuracy: 0.8321
# Epoch 319/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 0.4442 - categorical_accuracy: 0.8672
# Epoch 320/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 0.3947 - categorical_accuracy: 0.8641
# Epoch 321/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 0.3384 - categorical_accuracy: 0.8931
# Epoch 322/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 0.2975 - categorical_accuracy: 0.9053
# Epoch 323/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 0.5274 - categorical_accuracy: 0.8290
# Epoch 324/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 0.6625 - categorical_accuracy: 0.7893
# Epoch 325/2000
# 21/21 [==============================] - 1s 41ms/step - loss: 0.4346 - categorical_accuracy: 0.8672
# Epoch 326/2000
# 21/21 [==============================] - 1s 41ms/step - loss: 0.3833 - categorical_accuracy: 0.8824
# Epoch 327/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 0.4667 - categorical_accuracy: 0.8336
# Epoch 328/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 1.2110 - categorical_accuracy: 0.7588
# Epoch 329/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 9.2340 - categorical_accuracy: 0.8183
# Epoch 330/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 0.9431 - categorical_accuracy: 0.7008
# Epoch 331/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 0.6293 - categorical_accuracy: 0.8076
# Epoch 332/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 0.4564 - categorical_accuracy: 0.8550
# Epoch 333/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 0.3786 - categorical_accuracy: 0.8809
# Epoch 334/2000
# 21/21 [==============================] - 1s 44ms/step - loss: 0.3445 - categorical_accuracy: 0.8885
# Epoch 335/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 0.2918 - categorical_accuracy: 0.9008
# Epoch 336/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 0.2740 - categorical_accuracy: 0.9145
# Epoch 337/2000
# 21/21 [==============================] - 1s 41ms/step - loss: 0.2922 - categorical_accuracy: 0.9038
# Epoch 338/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 0.3383 - categorical_accuracy: 0.8901
# Epoch 339/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 0.4083 - categorical_accuracy: 0.8534
# Epoch 340/2000
# 21/21 [==============================] - 1s 44ms/step - loss: 0.3223 - categorical_accuracy: 0.8870
# Epoch 341/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 0.3217 - categorical_accuracy: 0.8824
# Epoch 342/2000
# 21/21 [==============================] - 1s 40ms/step - loss: 0.2570 - categorical_accuracy: 0.9206
# Epoch 343/2000
# 21/21 [==============================] - 1s 40ms/step - loss: 0.2178 - categorical_accuracy: 0.9282
# Epoch 344/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 0.2189 - categorical_accuracy: 0.9282
# Epoch 345/2000
# 21/21 [==============================] - 1s 41ms/step - loss: 0.2227 - categorical_accuracy: 0.9252
# Epoch 346/2000
# 21/21 [==============================] - 1s 41ms/step - loss: 0.2865 - categorical_accuracy: 0.9008
# Epoch 347/2000
# 21/21 [==============================] - 1s 49ms/step - loss: 0.2449 - categorical_accuracy: 0.9099
# Epoch 348/2000
# 21/21 [==============================] - 1s 44ms/step - loss: 0.2136 - categorical_accuracy: 0.9252
# Epoch 349/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 0.2671 - categorical_accuracy: 0.8916
# Epoch 350/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 0.2973 - categorical_accuracy: 0.8931
# Epoch 351/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 0.3662 - categorical_accuracy: 0.8779
# Epoch 352/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 0.2391 - categorical_accuracy: 0.9145
# Epoch 353/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 0.2021 - categorical_accuracy: 0.9282
# Epoch 354/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 0.2424 - categorical_accuracy: 0.9099
# Epoch 355/2000
# 21/21 [==============================] - 1s 40ms/step - loss: 0.1834 - categorical_accuracy: 0.9389
# Epoch 356/2000
# 21/21 [==============================] - 1s 44ms/step - loss: 0.1901 - categorical_accuracy: 0.9344
# Epoch 357/2000
# 21/21 [==============================] - 1s 42ms/step - loss: 0.2754 - categorical_accuracy: 0.8992
# Epoch 358/2000
# 21/21 [==============================] - 1s 46ms/step - loss: 0.3565 - categorical_accuracy: 0.8611
# Epoch 359/2000
# 21/21 [==============================] - 1s 44ms/step - loss: 0.2536 - categorical_accuracy: 0.9145
# Epoch 360/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 0.2391 - categorical_accuracy: 0.9282
# Epoch 361/2000
# 21/21 [==============================] - 1s 52ms/step - loss: 0.2417 - categorical_accuracy: 0.9084
# Epoch 362/2000
# 21/21 [==============================] - 1s 41ms/step - loss: 0.1528 - categorical_accuracy: 0.9588
# Epoch 363/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 0.2079 - categorical_accuracy: 0.9221
# Epoch 364/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 0.1996 - categorical_accuracy: 0.9252
# Epoch 365/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 0.1536 - categorical_accuracy: 0.9466
# Epoch 366/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 0.1325 - categorical_accuracy: 0.9542
# Epoch 367/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 0.1315 - categorical_accuracy: 0.9542
# Epoch 368/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 0.1750 - categorical_accuracy: 0.9511
# Epoch 369/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 0.2754 - categorical_accuracy: 0.8824
# Epoch 370/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 0.2357 - categorical_accuracy: 0.9206
# Epoch 371/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 0.1696 - categorical_accuracy: 0.9328
# Epoch 372/2000
# 21/21 [==============================] - 1s 43ms/step - loss: 0.1793 - categorical_accuracy: 0.9389
# Epoch 373/2000
# 21/21 [==============================] - 1s 47ms/step - loss: 0.1634 - categorical_accuracy: 0.9435
# Epoch 374/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 0.3008 - categorical_accuracy: 0.8931
# Epoch 375/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 0.2046 - categorical_accuracy: 0.9237
# Epoch 376/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 0.5612 - categorical_accuracy: 0.8412
# Epoch 377/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 0.6549 - categorical_accuracy: 0.7634
# Epoch 378/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 0.2806 - categorical_accuracy: 0.9130
# Epoch 379/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 0.2206 - categorical_accuracy: 0.9405
# Epoch 380/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 0.1624 - categorical_accuracy: 0.9588
# Epoch 381/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 0.1511 - categorical_accuracy: 0.9481
# Epoch 382/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 0.2664 - categorical_accuracy: 0.9038
# Epoch 383/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 0.3791 - categorical_accuracy: 0.8718
# Epoch 384/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 0.3479 - categorical_accuracy: 0.8748
# Epoch 385/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 0.2815 - categorical_accuracy: 0.9191
# Epoch 386/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 0.1582 - categorical_accuracy: 0.9511
# Epoch 387/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 0.1334 - categorical_accuracy: 0.9618
# Epoch 388/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 0.1330 - categorical_accuracy: 0.9588
# Epoch 389/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 1.4994 - categorical_accuracy: 0.6550
# Epoch 390/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 8.1044 - categorical_accuracy: 0.0916
# Epoch 391/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 3.1508 - categorical_accuracy: 0.0519
# Epoch 392/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 2.9796 - categorical_accuracy: 0.0794
# Epoch 393/2000
# 21/21 [==============================] - 1s 40ms/step - loss: 2.9229 - categorical_accuracy: 0.0641
# Epoch 394/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 2.8942 - categorical_accuracy: 0.1008
# Epoch 395/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 2.9111 - categorical_accuracy: 0.0962
# Epoch 396/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 2.9682 - categorical_accuracy: 0.0931
# Epoch 397/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 2.9611 - categorical_accuracy: 0.0840
# Epoch 398/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 3.0396 - categorical_accuracy: 0.0458
# Epoch 399/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 2.9765 - categorical_accuracy: 0.0550
# Epoch 400/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 2.7643 - categorical_accuracy: 0.1328
# Epoch 401/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 2.6242 - categorical_accuracy: 0.1466
# Epoch 402/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 2.6066 - categorical_accuracy: 0.1603
# Epoch 403/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 2.5054 - categorical_accuracy: 0.2168
# Epoch 404/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 2.6301 - categorical_accuracy: 0.1695
# Epoch 405/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 2.5437 - categorical_accuracy: 0.2000
# Epoch 406/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 2.4468 - categorical_accuracy: 0.1847
# Epoch 407/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 2.4044 - categorical_accuracy: 0.1985
# Epoch 408/2000
# 21/21 [==============================] - 1s 39ms/step - loss: 2.8828 - categorical_accuracy: 0.1115
# Epoch 409/2000
# 21/21 [==============================] - 1s 40ms/step - loss: 2.7040 - categorical_accuracy: 0.1115
# Epoch 410/2000
# 21/21 [==============================] - 1s 38ms/step - loss: 2.5892 - categorical_accuracy: 0.1527
# Epoch 411/2000
# 21/21 [==============================] - 1s 41ms/step - loss: 2.5635 - categorical_accuracy: 0.1679
# Epoch 412/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 2.5030 - categorical_accuracy: 0.1908
# Epoch 413/2000
# 21/21 [==============================] - 1s 37ms/step - loss: 2.4455 - categorical_accuracy: 0.2061
# Epoch 414/2000
# ...
# Epoch 1866/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1867/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1868/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1869/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1870/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1871/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1872/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1873/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1874/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1875/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1876/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1877/2000
# 3/3 [==============================] - 0s 123ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1878/2000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1879/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1880/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1881/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1882/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1883/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1884/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1885/2000
# 3/3 [==============================] - 0s 141ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1886/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1887/2000
# 3/3 [==============================] - 0s 105ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1888/2000
# 3/3 [==============================] - 0s 106ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1889/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1890/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1891/2000
# 3/3 [==============================] - 0s 107ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1892/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1893/2000
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1894/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1895/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1896/2000
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1897/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1898/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1899/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1900/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1901/2000
# 3/3 [==============================] - 0s 110ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1902/2000
# 3/3 [==============================] - 0s 110ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1903/2000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1904/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1905/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1906/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1907/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1908/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1909/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1910/2000
# 3/3 [==============================] - 0s 108ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1911/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1912/2000
# 3/3 [==============================] - 0s 105ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1913/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1914/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1915/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1916/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1917/2000
# 3/3 [==============================] - 0s 106ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1918/2000
# 3/3 [==============================] - 0s 112ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1919/2000
# 3/3 [==============================] - 0s 110ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1920/2000
# 3/3 [==============================] - 0s 118ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1921/2000
# 3/3 [==============================] - 0s 109ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1922/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1923/2000
# 3/3 [==============================] - 0s 128ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1924/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1925/2000
# 3/3 [==============================] - 0s 106ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1926/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1927/2000
# 3/3 [==============================] - 0s 155ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1928/2000
# 3/3 [==============================] - 0s 115ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1929/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1930/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1931/2000
# 3/3 [==============================] - 0s 116ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1932/2000
# 3/3 [==============================] - 0s 115ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1933/2000
# 3/3 [==============================] - 0s 119ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1934/2000
# 3/3 [==============================] - 0s 118ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1935/2000
# 3/3 [==============================] - 0s 109ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1936/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1937/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1938/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1939/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1940/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1941/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1942/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1943/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1944/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1945/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1946/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1947/2000
# 3/3 [==============================] - 0s 105ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1948/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1949/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1950/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1951/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1952/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1953/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1954/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1955/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1956/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1957/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1958/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1959/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1960/2000
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1961/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1962/2000
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1963/2000
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1964/2000
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1965/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1966/2000
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1967/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1968/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1969/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1970/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1971/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1972/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1973/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1974/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1975/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1976/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1977/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1978/2000
# 3/3 [==============================] - 0s 107ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1979/2000
# 3/3 [==============================] - 0s 133ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1980/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1981/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1982/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1983/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1984/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1985/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1986/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1987/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1988/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1989/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1990/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1991/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1992/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1993/2000
# 3/3 [==============================] - 0s 127ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1994/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1995/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1996/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1997/2000
# 3/3 [==============================] - 0s 128ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1998/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1999/2000
# 3/3 [==============================] - 0s 109ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 2000/2000
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000

# %%
model.summary()

# %%
import visualkeras
from PIL import ImageFont
font = ImageFont.truetype("arial.ttf", 12)
visualkeras.layered_view(model, legend=True, font=font,spacing=100)

# %% [markdown]
# # Make Predictions

# %%
res = model.predict(X_test)

# %%
actions[np.argmax(res[4])]

# %%
actions[np.argmax(y_test[4])]

# %% [markdown]
# # Save Weights

# %%
model.save('./model.h5')
model.save_weights('./model_weights.h5');

# %%
del model

# %%
import tensorflow as tf
model = tf.keras.models.load_model('model.h5')

# %%
model.load_weights('model_weights.h5')

# %% [markdown]
# # Evaluation using Confusion Matrix

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_test)

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat)

# %%
accuracy_score(ytrue, yhat)

# %% [markdown]
# # Realtime Test

# %%
from scipy import stats

# %%
colors = [(245,117,16), (117,245,16), (16,117,245)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
# 1. New detection variables
sequence = []
sentence = []
predictions = []
threshold = 0.5

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))
            
            
        #3. Viz logic
            if np.unique(predictions[-10:])[0]==np.argmax(res): 
                if res[np.argmax(res)] > threshold: 
                    
                    if len(sentence) > 0: 
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()

# %%
# !pip install numpy --upgrade

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp
import tensorflow as tf

signs = ['Hello','Shuvo Shokal','Apni','Kemon','Achen','Ami','Valo Achi','Ajker','Dinta','Shundor','Mach','Doya kore','Dekhte','SOS','Koita Baje','Dukkhito','Dhonnobad','Shahajjo Korte Pari','Bagh','Boi','Mobile','2','Ashirbad']
actions = np.array(['Hello','Shuvo Shokal','Apni','Kemon','Achen','Ami','Valo Achi','Ajker','Dinta','Shundor','Mach','Doya kore','Dekhte','SOS','Koita Baje','Dukkhito','Dhonnobad','Shahajjo Korte Pari','Bagh','Boi','Mobile','2','Ashirbad'])


mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR-CONVERSION BGR-to-RGB
    image.flags.writeable = False                  # Convert image to not-writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Convert image to writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR-COVERSION RGB-to-BGR
    return image, results

colors = [(245,117,16), (117,245,16), (16,117,245)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

def draw_styled_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             ) 
    
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])
    
# 1. New detection variables
sequence = []
sentence = []
predictions = []
threshold = 0.5

model = tf.keras.models.load_model('model.h5')
model.load_weights('model_weights.h5')
model.summary()

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        #print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            #print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))
            
            
        #3. Viz logic
            if np.unique(predictions[-10:])[0]==np.argmax(res): 
                if res[np.argmax(res)] > threshold: 
                    
                    if len(sentence) > 0: 
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Viz probabilities
            #image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        #print(sentence)
        #word = sentence[-1:]
        #convert_to_audio(word[0]) if (len(word) != 0) else print("word not detected yet")
        #convert_to_audio(word[0])
        
        # Show to screen
        cv2.imshow('Realtime LSTM Sign Language Detection', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
